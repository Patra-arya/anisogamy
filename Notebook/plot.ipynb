# %%
import numpy as np
import matplotlib.pyplot as plt
from anisogamy.plot import (
    plot_best_response, plot_cobweb, plot_bifurcation
)

# %%
plot_best_response(alpha=1.0, beta=10.0,
                    save_path='/Users....figures/best_response.png') 
plt.show()

# %%
plot_cobweb(m0=2.5, alpha=1.0, beta=1.0,
            save_path='/Users....figures/cobweb_spiral_in.png')    # should spiral inward
plt.show()

# %%
plot_cobweb(m0=3.0, alpha=1.0, beta=10.0, 
            save_path='/Users....figures/cobweb_spiral_out.png')   # should spiral outward to a 2-cycle
plt.show()

# %%
plot_bifurcation(alpha=2.0, betas=np.linspace(1, 30, 200), 
                 save_path='/Users....figures/bifurcation.png')
plt.show()
